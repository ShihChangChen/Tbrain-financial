# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import xgboost as xgb

# %%
CIF = pd.read_csv('data/TBN_CIF.csv',index_col='CUST_NO')  # 顧客基本資料
RECENT_DT = pd.read_csv('data/TBN_RECENT_DT.csv', na_values='a',index_col='CUST_NO')  #近期投資行為

CUST_BEHAVIOR = pd.read_csv('data/TBN_CUST_BEHAVIOR.csv', index_col='CUST_NO') #顧客瀏覽網頁行為
CUST_BEHAVIOR_raw = pd.read_csv('data/TBN_CUST_BEHAVIOR.csv') #顧客瀏覽網頁行為


CC_APPLY = pd.read_csv('data/TBN_CC_APPLY.csv') # 信用卡, priority 10
FX_TXN = pd.read_csv('data/TBN_FX_TXN.csv')    # 外匯, priority 1
LN_APPLY = pd.read_csv('data/TBN_LN_APPLY.csv')  # 信貸, priority 20
WM_TXN = pd.read_csv('data/TBN_WM_TXN.csv')  # 信託, priority 20

TBN = pd.read_csv('data/TBN_Y_ZERO.csv')  # 信託, priority 20

# %%
print('CIF shape:( %i, %i)'%(CIF.shape[0],CIF.shape[1]))
print('CUST_BEHAVIOR shape:( %i, %i)'%(CUST_BEHAVIOR.shape[0],CUST_BEHAVIOR.shape[1]))
print('CUST_BEHAVIOR_raw shape:( %i, %i)'%(CUST_BEHAVIOR_raw.shape[0],CUST_BEHAVIOR_raw.shape[1]))
print('RECENT_DT. shape:( %i, %i)'%(RECENT_DT.shape[0],RECENT_DT.shape[1]))
print('CC_APPLY shape:( %i, %i)'%(CC_APPLY.shape[0],CC_APPLY.shape[1]))
print('FX_TXN shape:( %i, %i)'%(FX_TXN.shape[0],FX_TXN.shape[1]))
print('LN_APPLY shape:( %i, %i)'%(LN_APPLY.shape[0],LN_APPLY.shape[1]))
print('WM_TXN shape:( %i, %i)'%(WM_TXN.shape[0],WM_TXN.shape[1]))
print('TBN shape:( %i, %i)'%(TBN.shape[0],TBN.shape[1]))
# Out:
# CIF shape:( 187679, 7)
# CUST_BEHAVIOR shape:( 2209864, 2)
# CUST_BEHAVIOR_raw shape:( 2209864, 3)
# RECENT_DT. shape:( 195000, 4)
# CC_APPLY shape:( 54393, 2)
# FX_TXN shape:( 507185, 3)
# LN_APPLY shape:( 6741, 4)
# WM_TXN shape:( 36763, 5)
# TBN shape:( 30000, 5)

# %%
print(CIF.head())
CIF.loc['W7ADZSWYXEMHB7JQ']
# Out:
#                   AGE  CHILDREN_CNT  CUST_START_DT  EDU_CODE GENDER_CODE  \
# CUST_NO
# UFUIMEGMK2KTIWI4    1           NaN            2.0       NaN         NaN
# 3HJN2X_LGBHBKILI    3           0.0         9393.0       NaN         NaN
# MNEZK2O3OE-JHYBW    4           0.0         2912.0       3.0           M
# W7ADZSWYXEMHB7JQ    4           0.0         8332.0       5.0           M
# ODB6BA6ORHL2UYZE    4           0.0          744.0       3.0           M
#
#                   INCOME_RANGE_CODE  WORK_MTHS
# CUST_NO
# UFUIMEGMK2KTIWI4                NaN        NaN
# 3HJN2X_LGBHBKILI                1.0        NaN
# MNEZK2O3OE-JHYBW                2.0        2.0
# W7ADZSWYXEMHB7JQ                2.0        1.0
# ODB6BA6ORHL2UYZE                2.0        1.0
# AGE                     4
# CHILDREN_CNT            0
# CUST_START_DT        8332
# EDU_CODE                5
# GENDER_CODE             M
# INCOME_RANGE_CODE       2
# WORK_MTHS               1
# Name: W7ADZSWYXEMHB7JQ, dtype: object

# %%
print(RECENT_DT.head())
RECENT_DT['CC_RECENT_DT']=RECENT_DT['CC_RECENT_DT'].fillna(0)
RECENT_DT['FX_RECENT_DT']=RECENT_DT['FX_RECENT_DT'].fillna(0)
RECENT_DT['LN_RECENT_DT']=RECENT_DT['LN_RECENT_DT'].fillna(0)
RECENT_DT['WM_RECENT_DT']=RECENT_DT['WM_RECENT_DT'].fillna(0)
print('CC_RECENT_DT: %.1f, %.1f '%(min(RECENT_DT['CC_RECENT_DT']), max(RECENT_DT['CC_RECENT_DT'])))
print('FX_RECENT_DT: %.1f, %.1f '%(min(RECENT_DT['FX_RECENT_DT']), max(RECENT_DT['FX_RECENT_DT'])))
print('LN_RECENT_DT: %.1f, %.1f '%(min(RECENT_DT['LN_RECENT_DT']), max(RECENT_DT['LN_RECENT_DT'])))
print('WM_RECENT_DT: %.1f, %.1f '%(min(RECENT_DT['WM_RECENT_DT']), max(RECENT_DT['WM_RECENT_DT'])))
# Out:
#                   CC_RECENT_DT  FX_RECENT_DT  LN_RECENT_DT  WM_RECENT_DT
# CUST_NO
# UTYYSZRISTNCDCGU           NaN           NaN           NaN           NaN
# 4IKO82Q8ZY2X2VAK           NaN           NaN           NaN           NaN
# EP2OI8DQMZFAHBEA        9214.0           NaN           NaN           NaN
# 83A1N8HQ4CLT56IY        9393.0        9438.0           NaN        9368.0
# SURN2CDMNHCL4SJC        7318.0        9445.0           NaN        8154.0
# CC_RECENT_DT: 0.0, 9447.0
# FX_RECENT_DT: 0.0, 9447.0
# LN_RECENT_DT: 0.0, 9445.0
# WM_RECENT_DT: 0.0, 9445.0

# %%
print(CUST_BEHAVIOR.head())
print('VISITDATE: %.1f, %.1f '%(min(CUST_BEHAVIOR['VISITDATE']), max(CUST_BEHAVIOR['VISITDATE'])))
# Out:
#                   VISITDATE                                               PAGE
# CUST_NO
# AZTHNWQ_LXMGIMYG       9462      http://www.esunbank.com.tw/gygrt/e2c/iougkjr/
# AZTHNWQ_LXMGIMYG       9528  https://www.esunbank.com.tw/gygrt/wgdqth/gsxri...
# 3PY428CHUQBULFIG       9458  https://www.esunbank.com.tw/edrn/deoxt/rgws-cg...
# JVPD1QUJWVLMZU8S       9457  https://www.esunbank.com.tw/edrn/pgusordq/fgpo...
# JVPD1QUJWVLMZU8S       9485  https://www.esunbank.com.tw/edrn/pgusordq/fgpo...
# VISITDATE: 9448.0, 9567.0

# %%
print(CC_APPLY.head())
print('CC_TXN_DT: %i, %i '%(min(CC_APPLY['TXN_DT']), max(CC_APPLY['TXN_DT'])))
# Out:
#             CUST_NO  TXN_DT
# 0  8H_N_K5ICM4NU7OG    9519
# 1  HXD9GCY3SPIYLJS0    9451
# 2  KSBOZ-TBPUDD9NMO    9502
# 3  MU8ROCNFDGSL0HJC    9549
# 4  RGZZAUSNHNXXESM4    9561
# CC_TXN_DT: 9448, 9567

# %%
print(FX_TXN.head())
print('FX_TXN_DT: %i, %i '%(min(FX_TXN['TXN_DT']), max(FX_TXN['TXN_DT'])))
# Out:
#             CUST_NO  TXN_DT  FX_TXN_AMT
# 0  MNEZK2O3OE-JHYBW    9562       26006
# 1  MNEZK2O3OE-JHYBW    9567       26009
# 2  MNEZK2O3OE-JHYBW    9557       26793
# 3  MNEZK2O3OE-JHYBW    9452       25981
# 4  MNEZK2O3OE-JHYBW    9451       26002
# FX_TXN_DT: 9448, 9567

# %%
print(LN_APPLY.head())
print('LN_TXN_DT: %i, %i '%(min(LN_APPLY['TXN_DT']), max(LN_APPLY['TXN_DT'])))
# Out:
#             CUST_NO  TXN_DT   LN_AMT LN_USE
# 0  JZKEGB1J3FEPXGWA    9455   904731     06
# 1  TKTH9UXLWDVLA8E4    9472  1218170     01
# 2  KZ0XPLZI-NGTHTDE    9505  1183088     01
# 3  BT5INBWYOZQK8CDY    9457   848097     05
# 4  Z5H7IUX8VPUMWWY8    9473   848097     01
# LN_TXN_DT: 9449, 9567

# %%
print(WM_TXN.head())
print('WM_TXN_DT: %i, %i '%(min(WM_TXN['TXN_DT']), max(WM_TXN['TXN_DT'])))
# Out:
#             CUST_NO  TXN_DT  CUST_RISK_CODE  INVEST_TYPE_CODE  WM_TXN_AMT
# 0  83A1N8HQ4CLT56IY    9476             3.0                 2      270684
# 1  B8ZNLMVWJOHCJ7LY    9546             3.0                 2      254794
# 2  -O2NVMT-W0WJHEAQ    9521             3.0                 2      797298
# 3  NRVZ15KRUYBNVLX0    9490             4.0                 2      439191
# 4  GAP3CQTQ-3K8OAHM    9513             4.0                 2      137037
# WM_TXN_DT: 9449, 9567

# %% [markdown]
# ## 1. 訓練資料集時間為 9447+1 (9448) ~ 9447+120 (9567) 之間，共120日之間產品交易/申請資訊．
# ## 2. 本次比賽是請參賽者預測在9447+121 (9568) ~ 9447+150 (9597) 時間區間內（共30日），顧客在四個產品線CC_IND, FX_IND, LN_IND, WM_IND是否會進行交易，若預測顧客該時間內於任一產品線交易一次以上，該產品線的預測值為1，否則為0．例如: 顧客序號12345，預測信用卡核卡1次，外匯交易2次，沒有信貸申請，信託交易3次，該筆預測資料應為: 12345,1,1,0,1 ．
# ## 3. TBN_Y_ZERO.csv則是提供給參賽者做為上傳範例資料檔使用，內部預設值是全部為0．

# %%
a=FX_TXN.groupby('CUST_NO', sort=False).max()

# %%
a
#a.loc['B8ZNLMVWJOHCJ7LY']
# Out:
#                   TXN_DT  FX_TXN_AMT
# CUST_NO
# MNEZK2O3OE-JHYBW    9567       47506
# 83A1N8HQ4CLT56IY    9557       53048
# SURN2CDMNHCL4SJC    9537       37617
# VMQ5HAOHU1RP1H-0    9561       27546
# XKLJ6BLFOZE-QWES    9472       29548
# J80JTJXD0ZC4AQPE    9456       72401
# 4W2SJLMLO6JTH5QA    9540       54439
# 5_TMYQNIHWRUZBZK    9533      101694
# N-_SFRR3-YRF2HRO    9457       60303
# V_UQSOPJF6BXUNDC    9452       38306
# XI5C9WHWCTH1JAOI    9465       43489
# B8DXBMZ5GQM9UM_8    9567       37412
# HERRVZUJSMND2FTG    9522       27441
# _-DWHHBPP7-3IC1I    9564       47759
# SW4RQJUG4BKSSG_M    9490       29892
# I_GRJRKLKACIKHHG    9547       87233
# _0SIAALKRYHUOZB8    9476       26018
# _S4CSY5B8AKREYUQ    9486       18820
# MJXGLDWPWQWNTY5Q    9539       55290
# ADFMQV7BG_YRMLJA    9455       17136
# DXSPTOBSFJTGL7A4    9554       29649
# Z2WUWZAXWNB7RTD0    9520       47340
# O1KDRBBJLVSY1DQI    9466       29672
# WAPK5THA4DYGTQIQ    9476       64374
# 0WJ39PZYGQBIYCOW    9561       97277
# EVEOIZLJOXD-BS6A    9546       35561
# PJTLOHTGFWBQAXKC    9508      118044
# NSE1MYRI8HXFVHNU    9471       81395
# NGJNTDDIYKV-YGIU    9532      107995
# PWIJHZSF1JB3WB1A    9535       86978
# ...                  ...         ...
# _PT5HFBEZJKOZ934    9554       19022
# WJ0EBQXNZILZ3WGQ    9550       14980
# KVF2_SHGVO85NAO0    9567       41635
# Q_UD6CQ_WMQ4UBS8    9567       50290
# 2G4FM7XXGRUDZU60    9567       11773
# NADHOOUT478IF5C0    9567       37776
# MKIRTI2LZXYTDTBG    9567       64999
# LLLC7FC-VXUSGGDI    9567       32929
# J1RXO_ERBII_SWYY    9567       41635
# B1WZCQNLZJ_WANSY    9567       67792
# FAF7P5MY-VSMT3TS    9567       56710
# YU0W4EIB9BXIFXME    9567       44894
# 1EHJP0D4JSRKX_LS    9567       44894
# V-PEQH4XQTXWSP88    9567       41635
# GKDHLCA6XINAIG6U    9567       47742
# O72SX1XO0GPTMDN4    9567       64999
# XCHRFOTBPFUVQ0FE    9567       47742
# PUHLBO3OTH9LXG6E    9567       32929
# APQW_ISW5KQZDZLK    9567       37776
# 4VNRR_AZJUBO0CWS    9567       44894
# MYHSPOXJAU2QBE04    9567       52604
# LTZTWCG-LQK_GASG    9567       26019
# AO35WBURWBCRAYX8    9567       56710
# RKFT-6272GQ8DFQY    9470       60308
# JM4Y4IF-I6WOW9XY    9550      149451
# PNCSTZS2UJJWRTGQ    9533      117418
# DJTE8TNEERCPCYUE    9455       64650
# CEQOAA-C--R3RN3K    9473       37389
# YWLZWPVSFCJIAXLK    9556      176092
# JGPNDATDQRGXNB4M    9484       41619
#
# [74111 rows x 2 columns]

# %%
FX = pd.concat((CIF,RECENT_DT ,a), axis=1, join_axes=[CIF.index], ignore_index=False)
print(FX.loc['SURN2CDMNHCL4SJC'])
#print(WM[WM['CUST_RISK_CODE']>0])
#print(WM[WM['WM_TXN_AMT']>0])
FX
# Out:
# AGE                      4
# CHILDREN_CNT             0
# CUST_START_DT         4677
# EDU_CODE                 2
# GENDER_CODE              M
# INCOME_RANGE_CODE        2
# WORK_MTHS                1
# CC_RECENT_DT          7318
# FX_RECENT_DT          9445
# LN_RECENT_DT             0
# WM_RECENT_DT          8154
# TXN_DT                9537
# FX_TXN_AMT           37617
# P1FVBSA86QJP2WRU    2           0.0         9156.0       NaN         NaN
# 1BXBUT7RNIWNKIEC    3           0.0         7820.0       6.0         NaN
# AC3WC0GE755JBZ1Q    4           0.0         7538.0       NaN         NaN
# 8H87FJNTIPJFLPNM    4           0.0         8146.0       NaN         NaN
# WSH5CAPDQIL-TFQI    4           0.0         3995.0       NaN         NaN
# JUMSYGP7-JJS_DBS    3           0.0         7839.0       6.0         NaN
# Z26TXGC9GPZ9YJFQ    3           0.0         7839.0       NaN         NaN
# XE1KS1TNT6_Q-ORQ    1           0.0         8930.0       NaN         NaN
# KXO3LJWFXUDPEABM    3           0.0         9239.0       NaN         NaN
# CZAPKMBM8QR7KUYE    3           0.0         7960.0       6.0         NaN
# XTXDWLOV37B-P31I    4           0.0         8094.0       NaN         NaN
# TDX2VQ1YHG__SCLG    3           0.0         8869.0       NaN         NaN
# AUZS6JH1QMJ-7I8G    4           0.0         9137.0       NaN         NaN
# P6VSDXYSKSRV4GGQ    3           0.0         7950.0       NaN         NaN
# ESYTEWHF1YKVNCH8    4           0.0         6726.0       6.0         NaN
# KDFMO1A0TVEDORWS    4           0.0         7565.0       6.0         NaN
# NR3SVKHZLSFQYHHC    2           0.0         7681.0       NaN         NaN
# OHFMTQXN4LDQ1D38    3           0.0         7903.0       NaN         NaN
# UA083GI6RNXUA2QA    4           NaN         1777.0       NaN         NaN
#
#                   INCOME_RANGE_CODE  WORK_MTHS  CC_RECENT_DT  FX_RECENT_DT  \
# CUST_NO
# UFUIMEGMK2KTIWI4                NaN        NaN           NaN           NaN
# 3HJN2X_LGBHBKILI                1.0        NaN           NaN           NaN
# MNEZK2O3OE-JHYBW                2.0        2.0           NaN           NaN
# W7ADZSWYXEMHB7JQ                2.0        1.0           NaN           NaN
# ODB6BA6ORHL2UYZE                2.0        1.0           NaN           NaN
# SURN2CDMNHCL4SJC                2.0        1.0        7318.0        9445.0
# 1SMBYIP5SSUNG1DW                1.0        1.0           NaN           NaN
# 8H_N_K5ICM4NU7OG                1.0        2.0           NaN           NaN
# OGMWH3NPW4BKLRBU                2.0        1.0        5410.0           0.0
# XKLJ6BLFOZE-QWES                2.0        1.0           NaN           NaN
# QAEI5S4M304UJ9PM                3.0        2.0           NaN           NaN
# BU0HPPLN-298U5ME                2.0        1.0           NaN           NaN
# ULHUEIYSCT_QC8WA                1.0        1.0           NaN           NaN
# 0LZWUXZGVN_TVZVQ                1.0        2.0           NaN           NaN
# PQIZYYFIRDENQZSW                2.0        1.0           NaN           NaN
# THE2EIIGHAUUINDO                1.0        1.0        8701.0           0.0
# ELAGQPCE8GTW7N98                4.0        1.0        7764.0        9032.0
# N-_SFRR3-YRF2HRO                1.0        NaN           0.0           0.0
# OBG-DBJQIC2GDPHU                2.0        1.0        7684.0           0.0
# PVX2PFINERRSM8QY                2.0        1.0        9435.0           0.0
# EVVQLLLJ8THQALKE                2.0        1.0           NaN           NaN
# FCTBTS-G-9NWVJOE                2.0        1.0           NaN           NaN
# QI0VWKJE-M5EPDAO                1.0        NaN           0.0           0.0
# L4HAZONALUFPCJTY                1.0        1.0           NaN           NaN
# TDX2VQ1YHG__SCLG           NaN           NaN     NaN         NaN
# AUZS6JH1QMJ-7I8G           0.0           0.0     NaN         NaN
# P6VSDXYSKSRV4GGQ           0.0           0.0     NaN         NaN
# ESYTEWHF1YKVNCH8           NaN           NaN     NaN         NaN
# KDFMO1A0TVEDORWS           0.0           0.0     NaN         NaN
# NR3SVKHZLSFQYHHC           NaN           NaN     NaN         NaN
# OHFMTQXN4LDQ1D38           NaN           NaN     NaN         NaN
# UA083GI6RNXUA2QA           0.0           0.0     NaN         NaN
#
# [187679 rows x 13 columns]

# %%
FX = pd.concat((CIF,RECENT_DT), axis=1, join_axes=[RECENT_DT.index], ignore_index=False)
print(FX.loc['SURN2CDMNHCL4SJC'])
#print(WM[WM['CUST_RISK_CODE']>0])
#print(WM[WM['WM_TXN_AMT']>0])
FX.shape
# Out:
# AGE                     4
# CHILDREN_CNT            0
# CUST_START_DT        4677
# EDU_CODE                2
# GENDER_CODE             M
# INCOME_RANGE_CODE       2
# WORK_MTHS               1
# CC_RECENT_DT         7318
# FX_RECENT_DT         9445
# LN_RECENT_DT            0
# WM_RECENT_DT         8154
# Name: SURN2CDMNHCL4SJC, dtype: object
# (195000, 11)

# %%
print(max(CUST_BEHAVIOR['VISITDATE']))
CUST_B_over30 = CUST_BEHAVIOR[CUST_BEHAVIOR['VISITDATE']<=(max(CUST_BEHAVIOR['VISITDATE'])-30)]
CUST_B_30_60 = CUST_BEHAVIOR[(CUST_BEHAVIOR['VISITDATE']<=(max(CUST_BEHAVIOR['VISITDATE'])-30)) & (CUST_BEHAVIOR['VISITDATE']>(max(CUST_BEHAVIOR['VISITDATE'])-60))]
CUST_B_60_90 = CUST_BEHAVIOR[(CUST_BEHAVIOR['VISITDATE']<=(max(CUST_BEHAVIOR['VISITDATE'])-60)) & (CUST_BEHAVIOR['VISITDATE']>(max(CUST_BEHAVIOR['VISITDATE'])-90))]
CUST_B_90_120 = CUST_BEHAVIOR[(CUST_BEHAVIOR['VISITDATE']<=(max(CUST_BEHAVIOR['VISITDATE'])-90)) & (CUST_BEHAVIOR['VISITDATE']>(max(CUST_BEHAVIOR['VISITDATE'])-120))]
CUST_B_in30 = CUST_BEHAVIOR[CUST_BEHAVIOR['VISITDATE']>(max(CUST_BEHAVIOR['VISITDATE'])-30)]
print('Over 30 days, max day: %i' %max(CUST_B_over30['VISITDATE']))
print(' 30~60  days, max day: %i' %max(CUST_B_30_60['VISITDATE']))
print(' 60~90  days, max day: %i' %max(CUST_B_60_90['VISITDATE']))
print(' 90~120  days, max day: %i' %max(CUST_B_90_120['VISITDATE']))
print('  in 30 days, min day: %i' %min(CUST_B_in30['VISITDATE']))
#print(CUST_B_over30.shape)
print(CUST_B_30_60.shape)
print(CUST_B_60_90.shape)
print(CUST_B_90_120.shape)
print(CUST_B_in30.shape)
# Out:
# 9567
# Over 30 days, max day: 9537
#  30~60  days, max day: 9537
#  60~90  days, max day: 9507
#  90~120  days, max day: 9477
#   in 30 days, min day: 9538
# (649891, 2)
# (601314, 2)
# (760446, 2)
# (198213, 2)

# %%
print(max(CUST_BEHAVIOR_raw['VISITDATE']))
CUST_B_over30_raw = CUST_BEHAVIOR_raw[CUST_BEHAVIOR_raw['VISITDATE']<=(max(CUST_BEHAVIOR_raw['VISITDATE'])-30)]
CUST_B_30_60_raw = CUST_BEHAVIOR_raw[(CUST_BEHAVIOR_raw['VISITDATE']<=(max(CUST_BEHAVIOR_raw['VISITDATE'])-30)) & (CUST_BEHAVIOR_raw['VISITDATE']>(max(CUST_BEHAVIOR_raw['VISITDATE'])-60))]
CUST_B_60_90_raw = CUST_BEHAVIOR_raw[(CUST_BEHAVIOR_raw['VISITDATE']<=(max(CUST_BEHAVIOR_raw['VISITDATE'])-60)) & (CUST_BEHAVIOR_raw['VISITDATE']>(max(CUST_BEHAVIOR_raw['VISITDATE'])-90))]
CUST_B_90_120_raw = CUST_BEHAVIOR_raw[(CUST_BEHAVIOR_raw['VISITDATE']<=(max(CUST_BEHAVIOR_raw['VISITDATE'])-90)) & (CUST_BEHAVIOR_raw['VISITDATE']>(max(CUST_BEHAVIOR_raw['VISITDATE'])-120))]
CUST_B_in30_raw = CUST_BEHAVIOR_raw[CUST_BEHAVIOR_raw['VISITDATE']>(max(CUST_BEHAVIOR_raw['VISITDATE'])-30)]
print('Over 30 days, max day: %i' %max(CUST_B_over30_raw['VISITDATE']))
print(' 30~60  days, max day: %i' %max(CUST_B_30_60_raw['VISITDATE']))
print(' 60~90  days, max day: %i' %max(CUST_B_60_90_raw['VISITDATE']))
print(' 90~120  days, max day: %i' %max(CUST_B_90_120_raw['VISITDATE']))
print('  in 30 days, min day: %i' %min(CUST_B_in30_raw['VISITDATE']))
#print(CUST_B_over30.shape)
print(CUST_B_30_60_raw.shape)
print(CUST_B_60_90_raw.shape)
print(CUST_B_90_120_raw.shape)
print(CUST_B_in30_raw.shape)
# Out:
# 9567
# Over 30 days, max day: 9537
#  30~60  days, max day: 9537
#  60~90  days, max day: 9507
#  90~120  days, max day: 9477
#   in 30 days, min day: 9538
# (649891, 3)
# (601314, 3)
# (760446, 3)
# (198213, 3)

# %%
CUST_BEHAVIOR.shape
# Out:
# (2209864, 2)

# %%
#total page count
PAGE_count = CUST_BEHAVIOR.groupby('PAGE').max()
PAGE_count.shape
# Out:
# (782, 1)

# %%
# 瀏覽網頁總人數
CUST_BEHAVIOR_gb = CUST_BEHAVIOR.groupby(('CUST_NO'), sort=False).max()
CUST_BEHAVIOR_gb.shape
# Out:
# (195000, 2)

# %%
# 30~120天瀏覽人數
CUST_B_over30_gb = CUST_B_over30.groupby(('CUST_NO'), sort=False).max()
CUST_B_over30_gb.shape
# Out:
# (180000, 2)

# %%
# 30~60 天瀏覽人數
CUST_B_30_60_gb = CUST_B_30_60.groupby(('CUST_NO'), sort=False).max()
print(CUST_B_30_60_gb.shape)
CUST_B_30_60_gb.head()
# Out:
# (86867, 2)
#                   VISITDATE                                               PAGE
# CUST_NO
# AZTHNWQ_LXMGIMYG       9528  https://www.esunbank.com.tw/gygrt/wgdqth/gsxri...
# KCAFRIBOU9F2SSJW       9511  https://www.esunbank.com.tw/gygrt/cugfkt/10603...
# JDVF4U8JUANEID68       9537  https://www.esunbank.com.tw/gygrt/mgmegutgdm/s...
# YXAILWW0FSCXRY2A       9520  https://www.esunbank.com.tw/edrn/pgusordq/fgpo...
# QAQSXBTCGA0SRGAO       9534  https://www.esunbank.com.tw/gygrt/wgdqth/gsxri...

# %%
# 60~90 天瀏覽人數
CUST_B_60_90_gb = CUST_B_60_90.groupby(('CUST_NO'), sort=False).max()
CUST_B_60_90_gb.shape
# Out:
# (86911, 2)

# %%
# 90~120 天瀏覽人數
CUST_B_90_120_gb = CUST_B_90_120.groupby(('CUST_NO'), sort=False).max()
CUST_B_90_120_gb.shape
# Out:
# (92858, 2)

# %%
# 近 30天瀏覽人數
CUST_B_in30_gb = CUST_B_in30.groupby(('CUST_NO'), sort=False).max()
CUST_B_in30_gb.shape
# Out:
# (30000, 2)

# %%
#CUST_B_in30_gb.to_csv('C_B_in30.csv')

# %%
# 30~60 天資料筆數
CUST_B_30_60_gbp = CUST_B_30_60_raw.groupby(('CUST_NO', 'PAGE'), sort=False).max()
CUST_B_30_60_gbp.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
# (197002, 1)

# %%
FX_TXN.head()
# Out:
#             CUST_NO  TXN_DT  FX_TXN_AMT
# 0  MNEZK2O3OE-JHYBW    9562       26006
# 1  MNEZK2O3OE-JHYBW    9567       26009
# 2  MNEZK2O3OE-JHYBW    9557       26793
# 3  MNEZK2O3OE-JHYBW    9452       25981
# 4  MNEZK2O3OE-JHYBW    9451       26002

# %%
max(FX_TXN['TXN_DT'])
# Out:
# 9567

# %% [markdown]
# ## 將 WM 分群

# %%
FX_30_60 = FX_TXN[(FX_TXN['TXN_DT']<=(max(FX_TXN['TXN_DT'])-30)) & (FX_TXN['TXN_DT']>(max(FX_TXN['TXN_DT'])-60))]
FX_60_90 = FX_TXN[(FX_TXN['TXN_DT']<=(max(FX_TXN['TXN_DT'])-60)) & (FX_TXN['TXN_DT']>(max(FX_TXN['TXN_DT'])-90))]
FX_90_120 = FX_TXN[(FX_TXN['TXN_DT']<=(max(FX_TXN['TXN_DT'])-90)) & (FX_TXN['TXN_DT']>(max(FX_TXN['TXN_DT'])-120))]
FX_in30 = FX_TXN[FX_TXN['TXN_DT']>(max(FX_TXN['TXN_DT'])-30)]

print(' 30~60  days, max day: %i' %max(FX_30_60['TXN_DT']))
print(' 60~90  days, max day: %i' %max(FX_60_90['TXN_DT']))
print(' 90~120  days, max day: %i' %max(FX_90_120['TXN_DT']))
print('  in 30 days, min day: %i' %min(FX_in30['TXN_DT']))

print(FX_30_60.shape)
print(FX_60_90.shape)
print(FX_90_120.shape)
print(FX_in30.shape)
# Out:
#  30~60  days, max day: 9537
#  60~90  days, max day: 9507
#  90~120  days, max day: 9477
#   in 30 days, min day: 9538
# (133614, 3)
# (94292, 3)
# (190077, 3)
# (89202, 3)

# %%
# 近30天WM人數
FX_in30_gb = FX_in30.groupby(('CUST_NO'), sort=False).max()
print(FX_in30_gb.shape)
FX_in30_gb.head()
# Out:
# (21509, 2)
#                   TXN_DT  FX_TXN_AMT
# CUST_NO
# MNEZK2O3OE-JHYBW    9567       26793
# 83A1N8HQ4CLT56IY    9557       36647
# VMQ5HAOHU1RP1H-0    9561       21655
# 4W2SJLMLO6JTH5QA    9540       49628
# B8DXBMZ5GQM9UM_8    9567       27428

# %%
#30~60天WM人數
FX_30_60_gb = FX_30_60.groupby(('CUST_NO'), sort=False).max()
print(FX_30_60_gb.shape)
FX_30_60_gb.head()
# Out:
# (31486, 2)
#                   TXN_DT  FX_TXN_AMT
# CUST_NO
# MNEZK2O3OE-JHYBW    9535       26022
# 83A1N8HQ4CLT56IY    9534       53048
# SURN2CDMNHCL4SJC    9537       37421
# VMQ5HAOHU1RP1H-0    9525       21655
# 5_TMYQNIHWRUZBZK    9533      101694

# %%
#60~90天WM人數
FX_60_90_gb = FX_60_90.groupby(('CUST_NO'), sort=False).max()
print(FX_60_90_gb.shape)
FX_60_90_gb.head()
# Out:
# (24881, 2)
#                   TXN_DT  FX_TXN_AMT
# CUST_NO
# 83A1N8HQ4CLT56IY    9507       42445
# SURN2CDMNHCL4SJC    9485       37463
# B8DXBMZ5GQM9UM_8    9507       31899
# _-DWHHBPP7-3IC1I    9507       47759
# SW4RQJUG4BKSSG_M    9490       29892

# %%
#90~120天WM人數
FX_90_120_gb = FX_90_120.groupby(('CUST_NO'), sort=False).max()
print(FX_90_120_gb.shape)
FX_90_120_gb.head()
# Out:
# (46634, 2)
#                   TXN_DT  FX_TXN_AMT
# CUST_NO
# MNEZK2O3OE-JHYBW    9472       47506
# SURN2CDMNHCL4SJC    9472       37617
# VMQ5HAOHU1RP1H-0    9464       27546
# XKLJ6BLFOZE-QWES    9472       29548
# J80JTJXD0ZC4AQPE    9456       72401

# %% [markdown]
# ## 將 WM 弄成 boolean, 且改為Y

# %%
# 將 WM 弄成 boolean, 且改為Y
print(FX_in30_gb.shape)
FX_in_30_Y = pd.DataFrame(FX_in30_gb['TXN_DT'].astype(bool), columns={"TXN_DT":'Y'})
FX_in_30_Y.rename(columns={"TXN_DT":"y"}, inplace=True)
print(FX_in_30_Y.shape)
FX_in_30_Y.head()
# Out:
# (21509, 2)
# (21509, 1)
#                      y
# CUST_NO
# MNEZK2O3OE-JHYBW  True
# 83A1N8HQ4CLT56IY  True
# VMQ5HAOHU1RP1H-0  True
# 4W2SJLMLO6JTH5QA  True
# B8DXBMZ5GQM9UM_8  True

# %%
print(FX_30_60_gb.shape)
FX_30_60_Y = pd.DataFrame(FX_30_60_gb['TXN_DT'].astype(bool), columns={"TXN_DT":'Y'})
FX_30_60_Y.rename(columns={"TXN_DT":"y"}, inplace=True)
print(FX_30_60_Y.shape)
FX_30_60_Y.head()
# Out:
# (31486, 2)
# (31486, 1)
#                      y
# CUST_NO
# MNEZK2O3OE-JHYBW  True
# 83A1N8HQ4CLT56IY  True
# SURN2CDMNHCL4SJC  True
# VMQ5HAOHU1RP1H-0  True
# 5_TMYQNIHWRUZBZK  True

# %%
print(FX_60_90_gb.shape)
FX_60_90_Y = pd.DataFrame(FX_60_90_gb['TXN_DT'].astype(bool), columns={"TXN_DT":'Y'})
FX_60_90_Y.rename(columns={"TXN_DT":"y"}, inplace=True)
print(FX_60_90_Y.shape)
FX_60_90_Y.head()
# Out:
# (24881, 2)
# (24881, 1)
#                      y
# CUST_NO
# 83A1N8HQ4CLT56IY  True
# SURN2CDMNHCL4SJC  True
# B8DXBMZ5GQM9UM_8  True
# _-DWHHBPP7-3IC1I  True
# SW4RQJUG4BKSSG_M  True

# %% [markdown]
# 80MMPXAEOOBMLLZS
# BVGAT9FJOQKNOXD0
# EBI_G_XSTJUYVY9W
# VI6OOMENGNASXNZG
#
#
# https://www.esunbank.com.tw/gygrt/cugfkt/1060222gcdufqodr/krfgz.htm
#     https://www.esunbank.com.tw/gygrt/cugfkt/1070210pda_dppqg/

# %%
# 第一組 training data
DATA_30_60 = pd.concat((CUST_B_30_60,CIF,RECENT_DT, FX_30_60_gb, FX_in_30_Y), axis=1 ,join_axes=[CUST_B_30_60.index])
print(DATA_30_60.shape)
DATA_30_60.loc['VI6OOMENGNASXNZG']#.head()
# Out:
# (649891, 16)
#                   VISITDATE  \
# CUST_NO
# VI6OOMENGNASXNZG       9527
# VI6OOMENGNASXNZG       9527
#
#                                                                PAGE  AGE  \
# CUST_NO
# VI6OOMENGNASXNZG  https://www.esunbank.com.tw/gygrt/cugfkt/10602...  NaN
# VI6OOMENGNASXNZG  https://www.esunbank.com.tw/gygrt/cugfkt/10702...  NaN
#
#                   CHILDREN_CNT  CUST_START_DT  EDU_CODE GENDER_CODE  \
# CUST_NO
# VI6OOMENGNASXNZG           NaN            NaN       NaN         NaN
# VI6OOMENGNASXNZG           NaN            NaN       NaN         NaN
#
#                   INCOME_RANGE_CODE  WORK_MTHS  CC_RECENT_DT  FX_RECENT_DT  \
# CUST_NO
# VI6OOMENGNASXNZG                NaN        NaN        8967.0           0.0
# VI6OOMENGNASXNZG                NaN        NaN        8967.0           0.0
#
#                   LN_RECENT_DT  WM_RECENT_DT  TXN_DT  FX_TXN_AMT    y
# CUST_NO
# VI6OOMENGNASXNZG           0.0           0.0     NaN         NaN  NaN
# VI6OOMENGNASXNZG           0.0           0.0     NaN         NaN  NaN

# %%
# 使用網路且真的在下個月有WM行為的數量
DATA_30_60[DATA_30_60['y']==True]
DATA_30_60_FX = pd.concat((CUST_B_30_60_gb,CIF,RECENT_DT, FX_30_60_gb, FX_in_30_Y), axis=1 ,join_axes=[FX_in_30_Y.index])
# 實際WM數量
print(DATA_30_60_FX.shape)
# 未使用網路卻交易數量
DATA_30_60_FX[DATA_30_60_FX['PAGE'].isnull()].shape
# Out:
# (21509, 16)
# (15214, 16)

# %%
# 第二組 training data
DATA_60_90 = pd.concat((CUST_B_60_90,CIF,RECENT_DT, FX_60_90_gb, FX_30_60_Y), axis=1 ,join_axes=[CUST_B_60_90.index])
print(DATA_60_90.shape)
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
# 3XTU38XKEMDMVJZI                2.0        2.0        9108.0        9417.0
#
#                   LN_RECENT_DT  WM_RECENT_DT  TXN_DT  FX_TXN_AMT    y
# CUST_NO
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0     NaN         NaN  NaN

# %%
# 使用網路且真的在下個月有WM行為的數量
DATA_60_90[DATA_60_90['y']==True]
DATA_60_90_FX = pd.concat((CUST_B_60_90_gb,CIF,RECENT_DT, FX_60_90_gb, FX_30_60_Y), axis=1 ,join_axes=[FX_30_60_Y.index])
# 實際WM數量
print(DATA_60_90_FX.shape)
# 未使用網路卻交易數量
DATA_60_90_FX[DATA_60_90_FX['PAGE'].isnull()].shape
# Out:
# (31486, 16)
# (22687, 16)

# %%
# 第三組 training data
# 3XTU38XKEMDMVJZI           0.0        9430.0  9477.0     81337.0  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0  9477.0     81337.0  NaN
# 3XTU38XKEMDMVJZI           0.0        9430.0  9477.0     81337.0  NaN

# %%
# 使用網路且真的在下個月有WM行為的數量
DATA_90_120[DATA_90_120['y']==True]
DATA_90_120_FX = pd.concat((CUST_B_90_120_gb,CIF,RECENT_DT, FX_90_120_gb, FX_60_90_Y), axis=1 ,join_axes=[FX_60_90_Y.index])
# 實際WM數量
print(DATA_90_120_FX.shape)
# 未使用網路卻交易數量
DATA_90_120_FX[DATA_90_120_FX['PAGE'].isnull()].shape
# Out:
# (24881, 16)
# (17325, 16)

# %%
#DATA = pd.concat((DATA_30_60,DATA_60_90,DATA_90_120), axis=0)
DATA = DATA_30_60
DATA.shape
# Out:
# (649891, 16)

# %%
test1 = pd.concat((CUST_B_in30,CIF,RECENT_DT, FX_in30_gb), axis=1 ,join_axes=[CUST_B_in30.index])
print(test1.shape)
test1.loc['8I6SQDGP9OQYUN1M']
# Out:
# (198213, 15)
#                   VISITDATE  \
# CUST_NO
# 8I6SQDGP9OQYUN1M       9553
# 8I6SQDGP9OQYUN1M       9553
# 8I6SQDGP9OQYUN1M       9553
#
#                                                                PAGE  AGE  \
# CUST_NO
# 8I6SQDGP9OQYUN1M      http://www.esunbank.com.tw/gygrt/e2c/iougkjr/  1.0
# 8I6SQDGP9OQYUN1M  http://www.esunbank.com.tw/gygrt/wgdqth/ixrfpq...  1.0
# 8I6SQDGP9OQYUN1M  http://www.esunbank.com.tw/gygrt/wgdqth/ixrfpq...  1.0
#
#                   CHILDREN_CNT  CUST_START_DT  EDU_CODE GENDER_CODE  \
# CUST_NO
# 8I6SQDGP9OQYUN1M           0.0         7754.0       6.0           F
# 8I6SQDGP9OQYUN1M           0.0         7754.0       6.0           F
# 8I6SQDGP9OQYUN1M           0.0         7754.0       6.0           F
#
#                   INCOME_RANGE_CODE  WORK_MTHS  CC_RECENT_DT  FX_RECENT_DT  \
# CUST_NO
# 8I6SQDGP9OQYUN1M                1.0        1.0        8323.0        9402.0
# 8I6SQDGP9OQYUN1M                1.0        1.0        8323.0        9402.0
# 8I6SQDGP9OQYUN1M                1.0        1.0        8323.0        9402.0
#
#                   LN_RECENT_DT  WM_RECENT_DT  TXN_DT  FX_TXN_AMT
# CUST_NO
# 8I6SQDGP9OQYUN1M           0.0        9396.0  9540.0     14979.0
# 8I6SQDGP9OQYUN1M           0.0        9396.0  9540.0     14979.0
# 8I6SQDGP9OQYUN1M           0.0        9396.0  9540.0     14979.0

# %%
ntrain = DATA.shape[0]
ntest = test1.shape[0]
all_data = pd.concat((DATA, test1))
print(ntrain)
print(ntest)
all_data.shape
# Out:
# 649891
# 198213
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# (848104, 16)

# %%
all_data.head()
# Out:
#                   AGE  CC_RECENT_DT  CHILDREN_CNT  CUST_START_DT  EDU_CODE  \
# CUST_NO
# AZTHNWQ_LXMGIMYG  3.0           0.0           0.0         7945.0       NaN
# KCAFRIBOU9F2SSJW  NaN        6396.0           NaN            NaN       NaN
# JDVF4U8JUANEID68  4.0        9022.0           0.0         2484.0       3.0
# JDVF4U8JUANEID68  4.0        9022.0           0.0         2484.0       3.0
# JDVF4U8JUANEID68  4.0        9022.0           0.0         2484.0       3.0
#
#                   FX_RECENT_DT  FX_TXN_AMT GENDER_CODE  INCOME_RANGE_CODE  \
# CUST_NO
# AZTHNWQ_LXMGIMYG           0.0         NaN           M                1.0
# KCAFRIBOU9F2SSJW           0.0         NaN         NaN                NaN
# JDVF4U8JUANEID68        9442.0     40185.0           F                4.0
# JDVF4U8JUANEID68        9442.0     40185.0           F                4.0
# JDVF4U8JUANEID68        9442.0     40185.0           F                4.0
#
#                   LN_RECENT_DT  \
# CUST_NO
# AZTHNWQ_LXMGIMYG           0.0
# KCAFRIBOU9F2SSJW           0.0
# JDVF4U8JUANEID68           0.0
# JDVF4U8JUANEID68           0.0
# JDVF4U8JUANEID68           0.0
#
#                                                                PAGE  TXN_DT  \
# CUST_NO
# AZTHNWQ_LXMGIMYG  https://www.esunbank.com.tw/gygrt/wgdqth/gsxri...     NaN
# KCAFRIBOU9F2SSJW  https://www.esunbank.com.tw/gygrt/cugfkt/10603...     NaN
# JDVF4U8JUANEID68  https://www.esunbank.com.tw/edrn/deoxt/drroxrc...  9527.0
# JDVF4U8JUANEID68  https://www.esunbank.com.tw/edrn/deoxt/drroxrc...  9527.0
# JDVF4U8JUANEID68  https://www.esunbank.com.tw/gygrt/mgmegutgdm/s...  9527.0
#
#                   VISITDATE  WM_RECENT_DT  WORK_MTHS     y
# CUST_NO
# AZTHNWQ_LXMGIMYG       9528           0.0        NaN   NaN
# KCAFRIBOU9F2SSJW       9511        8146.0        NaN   NaN
# JDVF4U8JUANEID68       9535        9442.0        1.0  True
# JDVF4U8JUANEID68       9537        9442.0        1.0  True
# JDVF4U8JUANEID68       9535        9442.0        1.0  True

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) *100
# 沒有missing的拿掉, 以遞減方式列出有missing的feature
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30] 
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
#                    Missing Ratio
# y                      83.531383
# TXN_DT                 68.477097
# FX_TXN_AMT             68.477097
# WORK_MTHS              36.759171
# EDU_CODE               30.890433
# GENDER_CODE            22.252695
# CHILDREN_CNT           21.503966
# INCOME_RANGE_CODE      21.487105
# CUST_START_DT          21.407162
# AGE                    21.407162

# %%
all_data['y'] = all_data['y'].fillna(False)

# %%
for col in ('LN_RECENT_DT','WM_RECENT_DT','FX_RECENT_DT','CC_RECENT_DT','TXN_DT','CUST_START_DT','FX_TXN_AMT'):
    all_data[col] = all_data[col].fillna(0)

# %%
for col in ('WORK_MTHS','EDU_CODE', 'GENDER_CODE', 'CHILDREN_CNT','INCOME_RANGE_CODE','AGE'):
    all_data[col] = all_data[col].fillna('None')

# %%
#all_data['y_True']

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) *100
# 沒有missing的拿掉, 以遞減方式列出有missing的feature
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30] 
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
#DATA_30_60[DATA_30_60['y']==True]

# %%
all_data = pd.get_dummies(all_data)
all_data.shape
# Out:
# (848104, 697)

# %%
train = all_data[:ntrain]
ytrain = train['y']
test = all_data[ntrain:]

# %%
train = train.drop(['y'], axis=1)
test = test.drop(['y'], axis=1)

# %%
print(train.shape)
print(ytrain.shape)
print(test.shape)
# Out:
# (649891, 696)
# (649891,)
# (198213, 696)

# %%
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split


X_train1, X_test1, y_train1, y_test1 = train_test_split(train, ytrain, random_state = np.random.randint(1,999), test_size = 0.20) #

# %%
print(X_train1.shape)
print(y_train1.shape)
# Out:
# (519912, 696)
# (519912,)

# %%
# eval_set =  [(X_test1, y_test1)]
# model = XGBClassifier(base_score=0.1, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=5, min_child_weight=5, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='multi:softprob', random_state=0,
#        reg_alpha=0.1, reg_lambda=1,  seed=None,
#        silent=True, subsample=0.9)
# model.fit(X_train1, y_train1, early_stopping_rounds=50, eval_metric="error", eval_set=eval_set,verbose=True)

# %%
eval_set =  [(X_test1, y_test1)]
model = XGBClassifier(scale_pos_weight=1.7,n_estimators=300, learning_rate=0.1)

# %%
model.fit(X_train1, y_train1, eval_metric="error", eval_set=eval_set,verbose=True, early_stopping_rounds=20)
# Out:
# [0]	validation_0-error:0.179344
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.179344
# [2]	validation_0-error:0.179344
# [3]	validation_0-error:0.179344
# [4]	validation_0-error:0.174451
# [5]	validation_0-error:0.174451
# [6]	validation_0-error:0.174459
# [7]	validation_0-error:0.174351
# [8]	validation_0-error:0.167927
# [9]	validation_0-error:0.174174
# [10]	validation_0-error:0.174174
# [11]	validation_0-error:0.167889
# [12]	validation_0-error:0.171312
# [13]	validation_0-error:0.174297
# [14]	validation_0-error:0.170397
# [15]	validation_0-error:0.170381
# [16]	validation_0-error:0.16882
# [17]	validation_0-error:0.165965
# [18]	validation_0-error:0.170481
# [19]	validation_0-error:0.166981
# [20]	validation_0-error:0.167219
# [21]	validation_0-error:0.167342
# [22]	validation_0-error:0.167189
# [23]	validation_0-error:0.16715
# [24]	validation_0-error:0.165273
# [25]	validation_0-error:0.165088
# [26]	validation_0-error:0.16515
# [27]	validation_0-error:0.164327
# [28]	validation_0-error:0.164019
# [29]	validation_0-error:0.164488
# [30]	validation_0-error:0.161349
# [31]	validation_0-error:0.160687
# [32]	validation_0-error:0.161357
# [33]	validation_0-error:0.161241
# [34]	validation_0-error:0.161349
# [35]	validation_0-error:0.161826
# [36]	validation_0-error:0.161518
# [37]	validation_0-error:0.161288
# [38]	validation_0-error:0.160718
# [39]	validation_0-error:0.16078
# [40]	validation_0-error:0.158956
# [41]	validation_0-error:0.15851
# [42]	validation_0-error:0.158456
# [43]	validation_0-error:0.160234
# [44]	validation_0-error:0.159133
# [45]	validation_0-error:0.158941
# [46]	validation_0-error:0.158849
# [47]	validation_0-error:0.158803
# [48]	validation_0-error:0.158756
# [49]	validation_0-error:0.157625
# [50]	validation_0-error:0.157372
# [51]	validation_0-error:0.157302
# [52]	validation_0-error:0.156587
# [53]	validation_0-error:0.156333
# [54]	validation_0-error:0.155194
# [55]	validation_0-error:0.153686
# [56]	validation_0-error:0.153863
# [57]	validation_0-error:0.153709
# [58]	validation_0-error:0.153302
# [59]	validation_0-error:0.152925
# [60]	validation_0-error:0.152694
# [61]	validation_0-error:0.152632
# [62]	validation_0-error:0.152725
# [63]	validation_0-error:0.150994
# [64]	validation_0-error:0.149016
# [65]	validation_0-error:0.147247
# [66]	validation_0-error:0.147532
# [67]	validation_0-error:0.147585
# [68]	validation_0-error:0.147632
# [69]	validation_0-error:0.147201
# [70]	validation_0-error:0.146924
# [71]	validation_0-error:0.147085
# [72]	validation_0-error:0.147185
# [73]	validation_0-error:0.14727
# [74]	validation_0-error:0.147093
# [75]	validation_0-error:0.147062
# [76]	validation_0-error:0.147093
# [77]	validation_0-error:0.147432
# [78]	validation_0-error:0.147247
# [79]	validation_0-error:0.146793
# [80]	validation_0-error:0.14657
# [81]	validation_0-error:0.147178
# [82]	validation_0-error:0.147532
# [83]	validation_0-error:0.144554
# [84]	validation_0-error:0.144539
# [85]	validation_0-error:0.144423
# [86]	validation_0-error:0.144031
# [87]	validation_0-error:0.143969
# [88]	validation_0-error:0.141531
# [89]	validation_0-error:0.140607
# [90]	validation_0-error:0.1415
# [91]	validation_0-error:0.141561
# [92]	validation_0-error:0.141446
# [93]	validation_0-error:0.140584
# [94]	validation_0-error:0.140353
# [95]	validation_0-error:0.140146
# [96]	validation_0-error:0.139969
# [97]	validation_0-error:0.139161
# [98]	validation_0-error:0.137768
# [99]	validation_0-error:0.136876
# [100]	validation_0-error:0.136791
# [101]	validation_0-error:0.13646
# [102]	validation_0-error:0.136391
# [103]	validation_0-error:0.135445
# [104]	validation_0-error:0.134768
# [105]	validation_0-error:0.134822
# [106]	validation_0-error:0.13503
# [107]	validation_0-error:0.13546
# [108]	validation_0-error:0.135337
# [109]	validation_0-error:0.135607
# [110]	validation_0-error:0.135591
# [111]	validation_0-error:0.135614
# [112]	validation_0-error:0.135468
# [113]	validation_0-error:0.13546
# [114]	validation_0-error:0.134829
# [115]	validation_0-error:0.134537
# [116]	validation_0-error:0.133322
# [117]	validation_0-error:0.133791
# [118]	validation_0-error:0.132829
# [119]	validation_0-error:0.132637
# [120]	validation_0-error:0.133137
# [121]	validation_0-error:0.133014
# [122]	validation_0-error:0.132945
# [123]	validation_0-error:0.132568
# [124]	validation_0-error:0.132137
# [125]	validation_0-error:0.131183
# [126]	validation_0-error:0.130975
# [127]	validation_0-error:0.130898
# [128]	validation_0-error:0.130552
# [129]	validation_0-error:0.13039
# [130]	validation_0-error:0.130675
# [131]	validation_0-error:0.130467
# [132]	validation_0-error:0.130475
# [133]	validation_0-error:0.129883
# [134]	validation_0-error:0.130021
# [135]	validation_0-error:0.12979
# [136]	validation_0-error:0.129698
# [137]	validation_0-error:0.129782
# [138]	validation_0-error:0.129621
# [139]	validation_0-error:0.129267
# [140]	validation_0-error:0.128959
# [141]	validation_0-error:0.129013
# [142]	validation_0-error:0.129052
# [143]	validation_0-error:0.128852
# [144]	validation_0-error:0.128929
# [145]	validation_0-error:0.128305
# [146]	validation_0-error:0.128013
# [147]	validation_0-error:0.128313
# [148]	validation_0-error:0.12839
# [149]	validation_0-error:0.128275
# [150]	validation_0-error:0.128675
# [151]	validation_0-error:0.128421
# [152]	validation_0-error:0.128352
# [153]	validation_0-error:0.128321
# [154]	validation_0-error:0.128251
# [155]	validation_0-error:0.128398
# [156]	validation_0-error:0.128113
# [157]	validation_0-error:0.128098
# [158]	validation_0-error:0.127559
# [159]	validation_0-error:0.127113
# [160]	validation_0-error:0.126505
# [161]	validation_0-error:0.126482
# [162]	validation_0-error:0.126482
# [163]	validation_0-error:0.126382
# [164]	validation_0-error:0.12592
# [165]	validation_0-error:0.125843
# [166]	validation_0-error:0.125782
# [167]	validation_0-error:0.125967
# [168]	validation_0-error:0.125551
# [169]	validation_0-error:0.125574
# [170]	validation_0-error:0.125482
# [171]	validation_0-error:0.125082
# [172]	validation_0-error:0.125151
# [173]	validation_0-error:0.125182
# [174]	validation_0-error:0.125097
# [175]	validation_0-error:0.125136
# [176]	validation_0-error:0.124897
# [177]	validation_0-error:0.124597
# [178]	validation_0-error:0.124582
# [179]	validation_0-error:0.124489
# [180]	validation_0-error:0.124828
# [181]	validation_0-error:0.124874
# [182]	validation_0-error:0.124936
# [183]	validation_0-error:0.124759
# [184]	validation_0-error:0.124305
# [185]	validation_0-error:0.123735
# [186]	validation_0-error:0.123897
# [187]	validation_0-error:0.123874
# [188]	validation_0-error:0.12262
# [189]	validation_0-error:0.12252
# [190]	validation_0-error:0.122435
# [191]	validation_0-error:0.122458
# [192]	validation_0-error:0.122397
# [193]	validation_0-error:0.122397
# [194]	validation_0-error:0.122097
# [195]	validation_0-error:0.122012
# [196]	validation_0-error:0.122212
# [197]	validation_0-error:0.122143
# [198]	validation_0-error:0.12192
# [199]	validation_0-error:0.121927
# [200]	validation_0-error:0.121797
# [201]	validation_0-error:0.121481
# [202]	validation_0-error:0.121297
# [203]	validation_0-error:0.121304
# [204]	validation_0-error:0.119773
# [205]	validation_0-error:0.11925
# [206]	validation_0-error:0.119204
# [207]	validation_0-error:0.119327
# [208]	validation_0-error:0.119142
# [209]	validation_0-error:0.119073
# [210]	validation_0-error:0.119035
# [211]	validation_0-error:0.119165
# [212]	validation_0-error:0.119719
# [213]	validation_0-error:0.11955
# [214]	validation_0-error:0.119542
# [215]	validation_0-error:0.118404
# [216]	validation_0-error:0.117596
# [217]	validation_0-error:0.117388
# [218]	validation_0-error:0.117304
# [219]	validation_0-error:0.117234
# [220]	validation_0-error:0.117396
# [221]	validation_0-error:0.117496
# [222]	validation_0-error:0.11715
# [223]	validation_0-error:0.117142
# [224]	validation_0-error:0.117119
# [225]	validation_0-error:0.116865
# [226]	validation_0-error:0.11688
# [227]	validation_0-error:0.116765
# [228]	validation_0-error:0.116757
# [229]	validation_0-error:0.116765
# [230]	validation_0-error:0.116603
# [231]	validation_0-error:0.116519
# [232]	validation_0-error:0.116288
# [233]	validation_0-error:0.116273
# [234]	validation_0-error:0.116403
# [235]	validation_0-error:0.116373
# [236]	validation_0-error:0.116434
# [237]	validation_0-error:0.116473
# [238]	validation_0-error:0.116488
# [239]	validation_0-error:0.11645
# [240]	validation_0-error:0.116534
# [241]	validation_0-error:0.116403
# [242]	validation_0-error:0.11655
# [243]	validation_0-error:0.116334
# [244]	validation_0-error:0.115926
# [245]	validation_0-error:0.116019
# [246]	validation_0-error:0.11605
# [247]	validation_0-error:0.115919
# [248]	validation_0-error:0.115888
# [249]	validation_0-error:0.115834
# [250]	validation_0-error:0.115796
# [251]	validation_0-error:0.115803
# [252]	validation_0-error:0.115734
# [253]	validation_0-error:0.115542
# [254]	validation_0-error:0.115303
# [255]	validation_0-error:0.11518
# [256]	validation_0-error:0.11508
# [257]	validation_0-error:0.114988
# [258]	validation_0-error:0.115265
# [259]	validation_0-error:0.115165
# [260]	validation_0-error:0.114242
# [261]	validation_0-error:0.113772
# [262]	validation_0-error:0.113264
# [263]	validation_0-error:0.113257
# [264]	validation_0-error:0.113195
# [265]	validation_0-error:0.112841
# [266]	validation_0-error:0.112834
# [267]	validation_0-error:0.112803
# [268]	validation_0-error:0.11268
# [269]	validation_0-error:0.112495
# [270]	validation_0-error:0.112472
# [271]	validation_0-error:0.112426
# [272]	validation_0-error:0.11208
# [273]	validation_0-error:0.112033
# [274]	validation_0-error:0.111857
# [275]	validation_0-error:0.11171
# [276]	validation_0-error:0.11141
# [277]	validation_0-error:0.111356
# [278]	validation_0-error:0.111626
# [279]	validation_0-error:0.111433
# [280]	validation_0-error:0.110795
# [281]	validation_0-error:0.110664
# [282]	validation_0-error:0.110726
# [283]	validation_0-error:0.110695
# [284]	validation_0-error:0.109779
# [285]	validation_0-error:0.10961
# [286]	validation_0-error:0.109579
# [287]	validation_0-error:0.109441
# [288]	validation_0-error:0.109441
# [289]	validation_0-error:0.109372
# [290]	validation_0-error:0.109372
# [291]	validation_0-error:0.109302
# [292]	validation_0-error:0.109302
# [293]	validation_0-error:0.109271
# [294]	validation_0-error:0.108679
# [295]	validation_0-error:0.108679
# [296]	validation_0-error:0.10881
# [297]	validation_0-error:0.108687
# [298]	validation_0-error:0.108333
# [299]	validation_0-error:0.108194
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=300,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1.7, seed=None,
#        silent=True, subsample=1)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
predicted=model.predict(X_test1)
print(accuracy_score(predicted, y_test1))

print(classification_report(y_test1,predicted ))
confusion_matrix(y_test1,predicted)
confusion_matrix(predicted,y_test1)
# Out:
# 0.8967140845828941
#              precision    recall  f1-score   support
#
#       False       0.93      0.94      0.93    101856
#        True       0.77      0.74      0.76     28123
#
# avg / total       0.90      0.90      0.90    129979
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([[95827,  7396],
#        [ 6029, 20727]])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
predicted=model.predict(X_test1)
print(accuracy_score(predicted, y_test1))

print(classification_report(y_test1,predicted ))
confusion_matrix(y_test1,predicted)
confusion_matrix(predicted,y_test1)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.8918055993660514
#              precision    recall  f1-score   support
#
#       False       0.93      0.93      0.93    101917
#        True       0.75      0.75      0.75     28062
#
# avg / total       0.89      0.89      0.89    129979
# array([[94891,  7037],
#        [ 7026, 21025]])

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 13))
xgb.plot_importance(model, max_num_features=30, height=0.5, ax=ax)

# %%
if test.shape[1]>X_train1.shape[1]:    
    test=test.drop('y',axis=1)

# %%
model.predict(test)
test['y'] = model.predict(test)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
test.shape
# Out:
# (198213, 697)

# %%
test.head()
# Out:
#                   CC_RECENT_DT  CUST_START_DT  FX_RECENT_DT  FX_TXN_AMT  \
# CUST_NO
# _PT5HFBEZJKOZ934        8658.0         2912.0           0.0     19022.0
# _PT5HFBEZJKOZ934        8658.0         2912.0           0.0     19022.0
# _PT5HFBEZJKOZ934        8658.0         2912.0           0.0     19022.0
# _PT5HFBEZJKOZ934        8658.0         2912.0           0.0     19022.0
# _PT5HFBEZJKOZ934        8658.0         2912.0           0.0     19022.0
#
#                   LN_RECENT_DT  TXN_DT  VISITDATE  WM_RECENT_DT  AGE_1.0  \
# CUST_NO
# _PT5HFBEZJKOZ934           0.0  9554.0       9553           0.0        0
# _PT5HFBEZJKOZ934           0.0  9554.0       9553           0.0        0
# _PT5HFBEZJKOZ934           0.0  9554.0       9553           0.0        0
# _PT5HFBEZJKOZ934           0.0  9554.0       9554           0.0        0
# _PT5HFBEZJKOZ934           0.0  9554.0       9562           0.0        0
#
#                   AGE_2.0  ...   \
# CUST_NO                    ...
# _PT5HFBEZJKOZ934        0  ...
# _PT5HFBEZJKOZ934        0  ...
# _PT5HFBEZJKOZ934        0  ...
# _PT5HFBEZJKOZ934        0  ...
# _PT5HFBEZJKOZ934        0  ...
#
#                   PAGE_https://www.esunbank.com.tw/s/wgdqthcdqcxqdtkor/  \
# CUST_NO
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
#
#                   PAGE_https://www.esunbank.com.tw/s/wgdqthcdqcxqdtkor/gsxruoeot  \
# CUST_NO
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
#
#                   PAGE_https://www.esunbank.com.tw/s/wgdqthcdqcxqdtkor/gsxruoeot/  \
# CUST_NO
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
# _PT5HFBEZJKOZ934                                                  0
#
#                   WORK_MTHS_1.0  WORK_MTHS_2.0  WORK_MTHS_3.0  WORK_MTHS_4.0  \
# CUST_NO
# _PT5HFBEZJKOZ934              1              0              0              0
# _PT5HFBEZJKOZ934              1              0              0              0
# _PT5HFBEZJKOZ934              1              0              0              0
# _PT5HFBEZJKOZ934              1              0              0              0
# _PT5HFBEZJKOZ934              1              0              0              0
#
#                   WORK_MTHS_5.0  WORK_MTHS_None     y
# CUST_NO
# _PT5HFBEZJKOZ934              0               0  True
# _PT5HFBEZJKOZ934              0               0  True
# _PT5HFBEZJKOZ934              0               0  True
# _PT5HFBEZJKOZ934              0               0  True
# _PT5HFBEZJKOZ934              0               0  True
#
# [5 rows x 697 columns]

# %%
test.groupby(test.index).max().shape
# Out:
# (30000, 697)

# %%
# 查看 test 資料預測為 True的數量
y_final = test.groupby(test.index, sort=False).max()
print((y_final[y_final['y']==True].shape[0]))
y_final[y_final['y']==True]
# Out:
# 2002
#                   CC_RECENT_DT  CUST_START_DT  FX_RECENT_DT  FX_TXN_AMT  \
# CUST_NO
# _PT5HFBEZJKOZ934        8658.0         2912.0           0.0     19022.0
# JDVF4U8JUANEID68        9022.0         2484.0        9442.0     40223.0
# 8I6SQDGP9OQYUN1M        8323.0         7754.0        9402.0     14979.0
# PVLZ97GRPBFRXUA4        8569.0         2220.0        9445.0     56710.0
# PQN2J1PZQASPI458           0.0         9053.0        9438.0     15572.0
# 2QUP-XZ1PM5QPLKS        9420.0         9417.0        9424.0      7229.0
# FJ1ZWOHWHGA5NRBG           0.0         4065.0        9379.0         0.0
# L6CZ9QPJFHZL22BI        8360.0         2730.0           0.0      9015.0
# 5BGLGS3CG7PQTD4Y        8570.0         5297.0        9435.0     55379.0
# NFKTDL9V8X-SGWCW        7391.0         2606.0        9438.0     21469.0
# PQUP4ESIA0DT5HQE        9259.0         5014.0        9443.0     25394.0
# PA5NX6DJOMAJXOOU        8330.0         4111.0        9361.0     24874.0
# CJ0JFD74V-NK1RJO        9445.0         9443.0           0.0     26018.0
# UTWXH9JD2LFWZMOG        8007.0         8001.0        9358.0     36164.0
# GNBOJV448VZ6KJRQ        9123.0         7110.0        9408.0     17234.0
# 4TSQYPMJ0UJSJ_DO        8601.0         8595.0        9379.0     33539.0
# JRO2RCK5HWI5LWXK           0.0         6446.0        9445.0     21697.0
# PSXAII77WHIP-U0S        8771.0         8574.0        9445.0     22971.0
# UWH3JQWWB5-LEM1A        9248.0         4026.0           0.0     18333.0
# OINGDATUDHAMIV8E           0.0         3360.0        9432.0     32929.0
# HLL4CSKTW4TXZ04Q           0.0         5371.0        9443.0     12136.0
# MQORVCL3GS6FVRYO        9276.0         7530.0        9406.0     24854.0
# QQ3PF32OKRL2EFZM           0.0         6629.0        9445.0     54621.0
# 3LXPQDIG7QA_QC3S        8790.0         4194.0        9444.0     32923.0
# JFRLGB_DG1OIVIA4        8846.0         7491.0        9386.0     32109.0
# FERYJFOXXAF-PGYG        9161.0         6760.0        9441.0     56734.0
# 979MQXICGRDF_JYK        5969.0  9555.0       9567           0.0        0
# JWSVPPLPZWVLEDRE           0.0  9548.0       9567        8297.0        0
# HJHFWYK33BEXTLEY           0.0  9567.0       9567           0.0        0
# Q1GEOF6LJPT0CW1Q           0.0  9564.0       9567           0.0        1
# HNJC0FR_AM7HEXMY           0.0  9540.0       9567           0.0        0
# X66UOU3UPNOFJ85A           0.0  9539.0       9567           0.0        0
# YZRNUATVMWTCILN8           0.0  9567.0       9567           0.0        0
# U89AK8RIRT9H8LUG           0.0  9563.0       9567           0.0        1
# ZU4QXYWKFAUW9BMS           0.0  9567.0       9567           0.0        1
# HVLN6ZWWVZMCTFF4           0.0  9567.0       9567           0.0        0
# CGTBPN-2HKNBSTIU           0.0  9557.0       9567           0.0        1
# VCIYFOUZLAFRO400           0.0  9540.0       9567           0.0        0
#
#                   AGE_2.0  ...   \
# CUST_NO                    ...
# _PT5HFBEZJKOZ934        0  ...
# JDVF4U8JUANEID68        0  ...
# 8I6SQDGP9OQYUN1M        0  ...
# PVLZ97GRPBFRXUA4        0  ...
# PQN2J1PZQASPI458        1  ...
# 2QUP-XZ1PM5QPLKS        0  ...
# FJ1ZWOHWHGA5NRBG        0  ...
# L6CZ9QPJFHZL22BI        0  ...
# 5BGLGS3CG7PQTD4Y        0  ...
# NFKTDL9V8X-SGWCW        0  ...
# PQUP4ESIA0DT5HQE        0  ...
# PA5NX6DJOMAJXOOU        0  ...
# CJ0JFD74V-NK1RJO        0  ...
# UTWXH9JD2LFWZMOG        0  ...
# GNBOJV448VZ6KJRQ        0  ...
# 4TSQYPMJ0UJSJ_DO        0  ...
# JRO2RCK5HWI5LWXK        0  ...
# PSXAII77WHIP-U0S        1  ...
# UWH3JQWWB5-LEM1A        0  ...
# OINGDATUDHAMIV8E        0  ...
# HLL4CSKTW4TXZ04Q        0  ...
# MQORVCL3GS6FVRYO        0  ...
# QQ3PF32OKRL2EFZM        0  ...
# 3LXPQDIG7QA_QC3S        0  ...
# JFRLGB_DG1OIVIA4        0  ...
# FERYJFOXXAF-PGYG        0  ...
# LR5XKFYNSQ8-6P4M        0  ...
# 39PI8JX6WDCJBB2I        0  ...
# 9KIC6JFP1XUHW75M        0  ...
# OVBLO3IIJULIBCYM        0  ...
# ...                   ...  ...
# M2DH0S9IC1OWUJIG        0  ...
# VCJSWY_BB69KWFII        1  ...
# R81IQIFDVRAUBWGW        1  ...
# ADIOE5ZW2HGXJBMW        0  ...
# ALC25DJRV6AOJQWM        0  ...
# 3QGBDDH8MHTRLP04        0  ...
# P4VLJY4M0TNHB9EY        0  ...
# G6AVNPMJHYVGGPZY        1  ...
# T6YQJUTMWM95TQBK        0  ...
# WMZEAVUA7PWR6Y1Q        0  ...
# BLX9MZWTXXBPXZZ0        0  ...
# K2K6FUD07PBUNZEO        0  ...
# 9JUEECHLRUWWFKSM        1  ...
# BV48OZJKFSYIFO5Q        0  ...
# B2-SCRIJ14ZKLHTY        0  ...
# 0WMECLH2EWHZXDFA        1  ...
# NO0CG4UJHZPH6FKS        0  ...
# CGTBPN-2HKNBSTIU              1              0              0              0
# VCIYFOUZLAFRO400              1              0              0              0
#
#                   WORK_MTHS_5.0  WORK_MTHS_None     y
# CUST_NO
# _PT5HFBEZJKOZ934              0               0  True
# JDVF4U8JUANEID68              0               0  True
# 8I6SQDGP9OQYUN1M              0               0  True
# PVLZ97GRPBFRXUA4              0               0  True
# PQN2J1PZQASPI458              0               1  True
# 2QUP-XZ1PM5QPLKS              0               0  True
# FJ1ZWOHWHGA5NRBG              0               1  True
# L6CZ9QPJFHZL22BI              0               0  True
# 5BGLGS3CG7PQTD4Y              0               0  True
# NFKTDL9V8X-SGWCW              0               0  True
# PQUP4ESIA0DT5HQE              0               0  True
# PA5NX6DJOMAJXOOU              0               0  True
# CJ0JFD74V-NK1RJO              0               0  True
# UTWXH9JD2LFWZMOG              0               0  True
# GNBOJV448VZ6KJRQ              0               1  True
# 4TSQYPMJ0UJSJ_DO              0               0  True
# JRO2RCK5HWI5LWXK              0               1  True
# PSXAII77WHIP-U0S              0               0  True
# UWH3JQWWB5-LEM1A              0               0  True
# OINGDATUDHAMIV8E              0               1  True
# HLL4CSKTW4TXZ04Q              0               1  True
# MQORVCL3GS6FVRYO              0               0  True
# QQ3PF32OKRL2EFZM              0               1  True
# 3LXPQDIG7QA_QC3S              0               0  True
# JFRLGB_DG1OIVIA4              0               0  True
# FERYJFOXXAF-PGYG              0               0  True
# LR5XKFYNSQ8-6P4M              0               0  True
# 39PI8JX6WDCJBB2I              0               0  True
# 9KIC6JFP1XUHW75M              0               1  True
# OVBLO3IIJULIBCYM              0               0  True
# ...                         ...             ...   ...
# M2DH0S9IC1OWUJIG              0               0  True
# VCJSWY_BB69KWFII              0               1  True
# R81IQIFDVRAUBWGW              0               0  True
# ADIOE5ZW2HGXJBMW              0               1  True
# ALC25DJRV6AOJQWM              0               0  True
# 3QGBDDH8MHTRLP04              0               0  True
# P4VLJY4M0TNHB9EY              0               1  True
# G6AVNPMJHYVGGPZY              0               0  True
# T6YQJUTMWM95TQBK              0               0  True
# WMZEAVUA7PWR6Y1Q              0               0  True
# BLX9MZWTXXBPXZZ0              0               1  True
# K2K6FUD07PBUNZEO              0               0  True
# 9JUEECHLRUWWFKSM              0               0  True
# BV48OZJKFSYIFO5Q              0               0  True
# B2-SCRIJ14ZKLHTY              0               0  True
# 0WMECLH2EWHZXDFA              0               0  True
# NO0CG4UJHZPH6FKS              0               0  True
# QUDUI_SWRUP-YPL8              0               0  True
# 979MQXICGRDF_JYK              0               0  True
# JWSVPPLPZWVLEDRE              0               0  True
# HJHFWYK33BEXTLEY              0               0  True
# Q1GEOF6LJPT0CW1Q              0               0  True
# HNJC0FR_AM7HEXMY              0               0  True
# X66UOU3UPNOFJ85A              0               0  True
# YZRNUATVMWTCILN8              0               0  True
# U89AK8RIRT9H8LUG              0               1  True
# ZU4QXYWKFAUW9BMS              0               0  True
# HVLN6ZWWVZMCTFF4              0               1  True
# CGTBPN-2HKNBSTIU              0               0  True
# VCIYFOUZLAFRO400              0               0  True
#
# [2002 rows x 697 columns]

# %%
ans = pd.concat((TBN.groupby('CUST_NO').max(),y_final['y']),axis=1, join_axes=[y_final.index])
ans.head()
# Out:
#                   CC_IND  FX_IND  LN_IND  WM_IND      y
# CUST_NO
# _PT5HFBEZJKOZ934       0       0       0       0   True
# 6STXUMWZRDCGSDDU       0       0       0       0  False
# JDVF4U8JUANEID68       0       0       0       0   True
# 8I6SQDGP9OQYUN1M       0       0       0       0   True
# R-TRDUV3GHTID31I       0       0       0       0  False

# %%
ans['FX_IND']=ans['y']

# %%
ans = ans.drop('y', axis=1)

# %%
ans.to_csv('FX.csv')

# %%
test['y']
# Out:
# CUST_NO
# _PT5HFBEZJKOZ934    False
# _PT5HFBEZJKOZ934    False
# _PT5HFBEZJKOZ934    False
# _PT5HFBEZJKOZ934    False
# _PT5HFBEZJKOZ934    False
# _PT5HFBEZJKOZ934    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# 6STXUMWZRDCGSDDU    False
# JDVF4U8JUANEID68    False
# JDVF4U8JUANEID68    False
# JDVF4U8JUANEID68    False
# JDVF4U8JUANEID68    False
# JDVF4U8JUANEID68    False
# JDVF4U8JUANEID68    False
# 8I6SQDGP9OQYUN1M    False
# R-TRDUV3GHTID31I    False
# R-TRDUV3GHTID31I    False
# J0DDOZLDFF03QBKW    False
# J0DDOZLDFF03QBKW    False
# HWAZJ_IO2-GACG_C    False
#                     ...
# GBGSO4CV37Q9HUGM    False
# GBGSO4CV37Q9HUGM    False
# GBGSO4CV37Q9HUGM    False
# GBGSO4CV37Q9HUGM    False
# GBGSO4CV37Q9HUGM    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# 2RZMYWSGN0NOMPS4    False
# VCIYFOUZLAFRO400    False
# 2RZMYWSGN0NOMPS4    False
# BRJGDJAQNPQOMHJQ    False
# BRJGDJAQNPQOMHJQ    False
# 3GLEJX78Z3IIW_9Y    False
# 3GLEJX78Z3IIW_9Y    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# FN2DBQ7_0OCJOSES    False
# Name: y, Length: 198213, dtype: bool
